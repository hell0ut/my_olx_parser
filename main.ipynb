# %%
import pandas as pd
df = pd.read_csv('data1667838573.131499.csv')
df
# Out:
#                                                  name        price  \
# 0   Msi GL65/full HD mat/i7-1750H/RTX2070 Super/16...  27 500 грн.
# 1   ASUS ROG Zephyrus M GU502G Intel i7-9750H 16 Г...  37 000 грн.
# 2   Dell Alienware M15R2/fullHD/i7-9750H/RTX2070/1...  35 500 грн.
# 3   Dell Alienware M15 / 15.6 240Hz / RTX2070 / i7...  35 490 грн.
# 4   Ігровий MSI GL65 Leopard 10SFR Intel i7-10750H...  36 000 грн.
# 5   Acer Predator Triton 500/i7-10750H/16GB/500GB/...  42 000 грн.
# 6   Ігровий Alienware M15 R3 Intel i7-10750H 16 Гб...  40 000 грн.
# 7   Alienware Area-51M 17" 144Hz/i7-9700K/RTX 2070...  62 000 грн.
# 8   #843 15” FHD msi gs65 i7-9750h/32gb/ssd 500gb/...  40 000 грн.
# 9   Msi GS65 /240Hz/full hd/ i7-9750H/RTX2080/RAM ...  36 000 грн.
# 10  Dell G7 7500 (i5-10300H, GTX 1660ti 6GB, 16gb,...  29 999 грн.
# 11  Msi GF66/fullhd 144 Hz/i7-10800H/RTX3050Ti/16G...  30 000 грн.
# 12  Dell G5 5500 [2020] / i7-10750H / 16RAM/ GTX 1...  31 490 грн.
# ...
